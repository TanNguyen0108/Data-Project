# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/tannguyen/Documents/CODE/DIM_SHOPEE_DISHES_comma.csv')
df
# Out:
# /var/folders/hl/66744hx91bg6k35x2s20h9780000gn/T/ipykernel_1333/1992518476.py:1: DtypeWarning: Columns (4,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/tannguyen/Documents/CODE/DIM_SHOPEE_DISHES_comma.csv')
#          catalog_id  dish_total_order catalog_name  catalog_rank  \
# 0           2635001             160.0      Món Hot         -11.0
# 1           2635001             136.0      Món Hot         -11.0
# 2           2635001             126.0      Món Hot         -11.0
# 3           2635001               4.0      Món Hot         -11.0
# 4           2635001               4.0      Món Hot         -11.0
# ...             ...               ...          ...           ...
# 1867750      671292             163.0         Menu           0.0
# 1867751      671292             151.0         Menu           0.0
# 1867752      671292             115.0         Menu           0.0
# ...

# %%
df_null = df[df['restaurant_id']>70000]
df_null
# Out:
#        restaurant_id                                     restaurant_url  \
# 0             786442               lien-hoa-ga-ac-oc-heo-tiem-thuoc-bac
# 3             786494                    bun-mi-vang-hu-tieu-mi-thap-cam
# 5             786523                    sinh-to-minh-thien-le-van-luong
# 6             786524                      hexagon-coffee-nguyen-van-qua
# 7             786530                    pho-nam-dinh-368-nguyen-van-qua
# ...              ...                                                ...
# 61569        1083136                            vu-heo-nuong-family-bbq
# 61570     1000033541  banh-canh-cua-tra-sua-thanh-tam-banh-canh-cua-...
# 61571         645072                             van-ngoc-com-ga-xoi-mo
# 61572         708242                     passio-coffee-nguyen-thai-binh
# 61573        1123133                       phuc-long-d1-1-nguyen-thi-tu
#
#                                          restaurant_name name_en  \
# ...

# %%
duplicates = df[df.duplicated(subset="dish_restaurant_id")]
duplicates
# Out:
#          catalog_id  dish_total_order catalog_name  catalog_rank  \
# 1           2635001             136.0      Món Hot         -11.0
# 2           2635001             126.0      Món Hot         -11.0
# 3           2635001               4.0      Món Hot         -11.0
# 4           2635001               4.0      Món Hot         -11.0
# 5           2635001               2.0      Món Hot         -11.0
# ...             ...               ...          ...           ...
# 1867750      671292             163.0         Menu           0.0
# 1867751      671292             151.0         Menu           0.0
# 1867752      671292             115.0         Menu           0.0
# 1867753      671292              93.0         Menu           0.0
# 1867754      671292              48.0         Menu           0.0
#
#         catalog_partner_catalog_id  catalog_description  dish_restaurant_id  \
# 1                              NaN                  NaN           1114911.0
# ...

# %%
df_check = df[df['dish_restaurant_id'].isnull()]
df_check
# Out:
# Empty DataFrame
# Columns: [catalog_id, dish_total_order, catalog_name, catalog_rank, catalog_partner_catalog_id, catalog_description, dish_restaurant_id, dish_id, dish_name, dish_partner_dish_id, dish_listing_status, dish_description, dish_total_like, dish_rank, dish_picture_label, dish_is_hidden, dish_price, dish_is_group_discount_item, dishes_property_info, url]
# Index: []

# %%
dish_restaurant_ids = df['dish_restaurant_id']
non_numeric_ids = []
for id_value in dish_restaurant_ids:
    if not pd.isnull(id_value) and not isinstance(id_value, (int, float)):
        non_numeric_ids.append(id_value)

print(non_numeric_ids)
# Out:
# ['Nga']

# %%
df['dish_restaurant_id'].loc[2008] = 'Nga'df['dish_restaurant_id'].loc[2008] = 'Nga'
# Out:
# 1141761.0

# %%
df['dish_restaurant_id'].loc[2008] = 1141761.0

# %%
df['dish_restaurant_id'].loc[2008]
# Out:
# 1141761.0

# %%
df
# Out:
#          catalog_id  dish_total_order catalog_name  catalog_rank  \
# 0           2635001             160.0      Món Hot         -11.0
# 1           2635001             136.0      Món Hot         -11.0
# 2           2635001             126.0      Món Hot         -11.0
# 3           2635001               4.0      Món Hot         -11.0
# 4           2635001               4.0      Món Hot         -11.0
# ...             ...               ...          ...           ...
# 1867750      671292             163.0         Menu           0.0
# 1867751      671292             151.0         Menu           0.0
# 1867752      671292             115.0         Menu           0.0
# 1867753      671292              93.0         Menu           0.0
# 1867754      671292              48.0         Menu           0.0
#
#         catalog_partner_catalog_id  catalog_description dish_restaurant_id  \
# 0                              NaN                  NaN          1114911.0
# ...

# %%
#set integer
df['catalog_id']=df['catalog_id'].astype(int)
df['dish_total_order']=df['dish_total_order'].astype(int)
df['catalog_rank']=df['catalog_rank'].astype(int)
df['dish_restaurant_id']=df['dish_restaurant_id'].astype(int)
df['dish_id']=df['dish_id'].astype(int)
df['dish_total_like']=df['dish_total_like'].astype(int)
df['dish_rank']=df['dish_rank'].astype(int)
df['dish_price']=df['dish_price'].astype(int)

# %%
df
# Out:
#          catalog_id  dish_total_order catalog_name  catalog_rank  \
# 0           2635001               160      Món Hot           -11
# 1           2635001               136      Món Hot           -11
# 2           2635001               126      Món Hot           -11
# 3           2635001                 4      Món Hot           -11
# 4           2635001                 4      Món Hot           -11
# ...             ...               ...          ...           ...
# 1867750      671292               163         Menu             0
# 1867751      671292               151         Menu             0
# 1867752      671292               115         Menu             0
# 1867753      671292                93         Menu             0
# 1867754      671292                48         Menu             0
#
#         catalog_partner_catalog_id  catalog_description  dish_restaurant_id  \
# 0                              NaN                  NaN             1114911
# ...

# %%
## clear comma
contain_comma = df['url'].str.contains(',')
comma_cells = df[contain_comma]
comma_cells
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 3
#       1 ## clear comma
#       2 contain_comma = df['url'].str.contains(',')
# ----> 3 comma_cells = df[contain_comma]
#       4 comma_cells
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
# ...

# %%
df['dish_description'] = df['dish_description'].str.replace(',', ';')

# %%
#checking nominate if contain comma in all columns
contains_comma = df.apply(lambda x: x.astype(str).str.contains(','), axis=1).any(axis=1)

comma_rows = df[contains_comma]

print(comma_rows)
# Out:
# Empty DataFrame
# Columns: [catalog_id, dish_total_order, catalog_name, catalog_rank, catalog_partner_catalog_id, catalog_description, dish_restaurant_id, dish_id, dish_name, dish_partner_dish_id, dish_listing_status, dish_description, dish_total_like, dish_rank, dish_picture_label, dish_is_hidden, dish_price, dish_is_group_discount_item, dishes_property_info, url]
# Index: []

# %%
df['url'].iloc[2787]
# Out:
# 'https://images.foody.vn/res/g1/1366/s1242x1242/foody-bun cha ca, ca dam, sua-635791347413356544.jpg'

# %%
df = df.drop(2787)

# %%
df = df.drop(109528)

# %%
df
# Out:
#          catalog_id  dish_total_order catalog_name  catalog_rank  \
# 0           2635001               160      Món Hot           -11
# 1           2635001               136      Món Hot           -11
# 2           2635001               126      Món Hot           -11
# 3           2635001                 4      Món Hot           -11
# 4           2635001                 4      Món Hot           -11
# ...             ...               ...          ...           ...
# 1867750      671292               163         Menu             0
# 1867751      671292               151         Menu             0
# 1867752      671292               115         Menu             0
# 1867753      671292                93         Menu             0
# 1867754      671292                48         Menu             0
#
#         catalog_partner_catalog_id  catalog_description  dish_restaurant_id  \
# 0                              NaN                  NaN             1114911
# ...

# %%
pd.to_csv('DIM_SHOPEE_DISHES_commaclean')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pd.to_csv('DIM_SHOPEE_DISHES_commaclean')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
df.to_csv('DIM_SHOPEE_DISHES_commaclean',index=False)

# %%
df
# Out:
#          catalog_id  dish_total_order catalog_name  catalog_rank  \
# 0           2635001               160      Món Hot           -11
# 1           2635001               136      Món Hot           -11
# 2           2635001               126      Món Hot           -11
# 3           2635001                 4      Món Hot           -11
# 4           2635001                 4      Món Hot           -11
# ...             ...               ...          ...           ...
# 1867750      671292               163         Menu             0
# 1867751      671292               151         Menu             0
# 1867752      671292               115         Menu             0
# 1867753      671292                93         Menu             0
# 1867754      671292                48         Menu             0
#
#         catalog_partner_catalog_id  catalog_description  dish_restaurant_id  \
# 0                              NaN                  NaN             1114911
# ...
